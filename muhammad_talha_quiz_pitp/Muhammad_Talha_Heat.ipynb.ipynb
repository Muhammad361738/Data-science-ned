# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('heart.csv')

# %%
df["target"]
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 298    0
# 299    0
# 300    0
# 301    0
# 302    0
# Name: target, Length: 303, dtype: int64

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
X = df[['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
       'exang', 'oldpeak', 'slope', 'ca', 'thal']]
y = df["target"]

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=40)

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(random_state=1)
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
y_pred = model.predict(X_test)

# %%
print(mean_absolute_error(y_test, y_pred))
accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
# Out:
# 0.2087912087912088
# 0.7912087912087912

# %% [markdown]
# ## Random forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model1 = RandomForestClassifier(random_state=1)
model1.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=1)

# %%
y_pred = model1.predict(X_test)

# %%
mean_absolute_error(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

print(accuracy)
# Out:
# 0.8461538461538461

# %% [markdown]
# ## Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
model2 = LogisticRegression(random_state=1)
model2.fit(X_train, y_train)
# Out:
# C:\Users\User\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=1)

# %%
y_pred = model2.predict(X_test)

# %%
mean_absolute_error(y_test, y_pred)
# Out:
# 0.08791208791208792

# %%
accuracy = accuracy_score(y_test, y_pred)
print(accuracy)
# Out:
# 0.9120879120879121

# %%
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.85      0.89        40
#            1       0.89      0.96      0.92        51
#
#     accuracy                           0.91        91
#    macro avg       0.92      0.91      0.91        91
# weighted avg       0.91      0.91      0.91        91

# %% [markdown]
# ## visulation

# %%
# import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt

# # Ensure age and chol are numeric
# df['age'] = pd.to_numeric(df['age'], errors='coerce')
# df['chol'] = pd.to_numeric(df['chol'], errors='coerce')

# # Define age bins
# bins = [0, 18, 30, 40, 50, 60, 100]
# labels = ['0-18', '19-30', '31-40', '41-50', '51-60', '60+']
# df['age_range'] = pd.cut(df['age'], bins=bins, labels=labels, right=False)

# # Drop missing
# df = df.dropna(subset=['age_range', 'chol'])

# # Calculate average cholesterol per age range
# avg_chol = df.groupby('age_range')['chol'].mean().reset_index()

# # Plot bar graph
# plt.figure(figsize=(10, 5))
# sns.barplot(data=avg_chol, x='age_range', y='chol', palette='viridis')
# plt.title('Average Cholesterol by Age Range')
# plt.xlabel('Age Range')
# plt.ylabel('Average Cholesterol')
# plt.tight_layout()
# plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12876\3493272284.py:18: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_chol = df.groupby('age_range')['chol'].mean().reset_index()
# C:\Users\User\AppData\Local\Temp\ipykernel_12876\3493272284.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=avg_chol, x='age_range', y='chol', palette='viridis')

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 

sns.set(style="whitegrid")

# Corrected feature name and fixed syntax
features = ["age", "trestbps", "chol", "thalach", "oldpeak"]

# Create the pairplot
pairplot = sns.pairplot(df[features + ["target"]], hue="target", palette="Set2")

# Set the title
pairplot.fig.suptitle("Pairplot of Features by Target", y=1.02)

# Show the plot
plt.show()
